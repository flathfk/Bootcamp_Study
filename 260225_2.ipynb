# %% [markdown]
# <a href="https://colab.research.google.com/github/flathfk/Bootcamp_Study/blob/main/260225_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile /content/crp-demo/server.js
#
# const express = require("express");
# const path = require("path");
# const app = express();
#
# app.get("/slow.css", (req, res) => {
#   setTimeout(() => {
#     res.sendFile(path.join(__dirname, "slow.css"));
#   }, 3000);
# });
#
# app.get("/block.js", (req, res) => {
#   setTimeout(() => {
#     res.sendFile(path.join(__dirname, "block.js"));
#   }, 2000);
# });
#
# app.use(express.static(__dirname));
#
# app.listen(3000, () => {
#   console.log("Server running on port 3000");
# });
# Out:
# Overwriting /content/crp-demo/server.js

# %%
# %%writefile /content/crp-demo/index.html
#
# <!DOCTYPE html>
# <html>
# <head>
#   <meta charset="UTF-8" />
#   <title>CRP Demo</title>
#   <link rel="stylesheet" href="/slow.css">
# </head>
#
# <body>
#   <h1>CRP Pipeline Demo</h1>
#   <p>Observe rendering delay.</p>
#
#   <div class="box"></div>
#
#   <script>
#     console.log("DOM parsing started");
#     document.addEventListener("DOMContentLoaded", () => {
#       console.log("DOMContentLoaded at", performance.now());
#     });
#     window.addEventListener("load", () => {
#       console.log("Load event at", performance.now());
#     });
#   </script>
#
#   <script src="/block.js"></script>
# </body>
# </html>
# Out:
# Overwriting /content/crp-demo/index.html

# %%
# %%writefile /content/crp-demo/slow.css
#
# body {
#   background: black;
#   color: white;
#   font-family: Arial;
# }
#
# .box {
#   width: 200px;
#   height: 200px;
#   background: red;
# }
# Out:
# Overwriting /content/crp-demo/slow.css

# %%
# %%writefile /content/crp-demo/block.js
#
# console.log("Blocking JS executed at", performance.now());
# Out:
# Overwriting /content/crp-demo/block.js

# %%
# %%writefile ex1.html
#
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#     <meta charset="UTF-8">
#     <title>블로그 시맨틱 레이아웃 실습</title>
# </head>
# <body>
#
#     <header>
#         <h1>심플 개발 블로그</h1>
#
#         <nav>
#             <ul>
#                 <li><a href="#">홈</a></li>
#                 <li><a href="#">프론트엔드</a></li>
#                 <li><a href="#">백엔드</a></li>
#                 <li><a href="#">방명록</a></li>
#             </ul>
#         </nav>
#     </header>
#
#     <main>
#         <section>
#             <h2>최신 포스트</h2>
#
#             <article>
#                 <h3>HTML5 시맨틱 태그란 무엇인가?</h3>
#                 <p>시맨틱 태그를 사용하면 웹 브라우저가 코드의 의미를 이해할 수 있습니다...</p>
#                 <time datetime="2026-02-21">2026년 2월 21일</time>
#             </article>
#
#             <article>
#                 <h3>CSS 레이아웃 기초: Flexbox</h3>
#                 <p>Flexbox를 활용하면 복잡한 레이아웃도 간단하게 구현할 수 있습니다...</p>
#                 <time datetime="2026-02-20">2026년 2월 20일</time>
#             </article>
#         </section>
#     </main>
#
#     <aside>
#         <section>
#             <h4>최근 댓글</h4>
#             <ul>
#                 <li>감사합니다! 큰 도움이 되었어요.</li>
#                 <li>다음 포스팅도 기대할게요.</li>
#             </ul>
#         </section>
#         <section>
#             <h4>인기 포스트</h4>
#             <ul>
#                 <li>시맨틱 태그 완벽 가이드</li>
#                 <li>웹 표준의 이해</li>
#             </ul>
#         </section>
#     </aside>
#
#     <footer>
#         <p>&copy; 2026 Simple Dev Blog. All rights reserved.</p>
#         <address>연락처: admin@devblog.com</address>
#     </footer>
#
# </body>
# </html>
# Out:
# Overwriting ex1.html

# %%
# %%writefile ex2.html
#
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>뉴스 포털 리스트 영역 실습</title>
# </head>
# <body>
#
#     <section>
#         <h2>오늘의 헤드라인</h2>
#
#         <article>
#             <figure>
#                 <img src="economy_news.jpg" alt="경제 정책 발표장 전경">
#                 <figcaption>정부 관계자가 새로운 경제 활성화 대책을 설명하고 있다.</figcaption>
#             </figure>
#
#             <h3><a href="#">정부, '민생 경제 회복'을 위한 전방위적 지원책 마련</a></h3>
#
#             <p>
#                 정부는 내달부터 소상공인 지원과 물가 안정을 골자로 하는 새로운 경제 정책을 시행합니다.
#                 이번 대책은 금리 인상으로 어려움을 겪는 취약 계층을 우선적으로...
#             </p>
#
#             <footer>
#                 <span>경제부 김철수 기자</span> |
#                 <time datetime="2026-02-21T09:30">2026년 2월 21일 09:30</time>
#             </footer>
#         </article>
#
#         <hr> <article>
#             <h3><a href="#">IT 트렌드: AI 기술이 접목된 시맨틱 웹의 미래</a></h3>
#             <p>
#                 인공지능 검색 엔진의 진화와 함께 웹 표준의 중요성이 다시금 대두되고 있습니다.
#                 단순한 텍스트를 넘어 의미를 가진 데이터로 웹을 구축하는 '시맨틱 마크업'은...
#             </p>
#             <footer>
#                 <span>IT 전문 이영희 기자</span> |
#                 <time datetime="2026-02-21T10:15">2026년 2월 21일 10:15</time>
#             </footer>
#         </article>
#
#         <hr>
#
#         <section>
#             <h4>이 시각 주요 단신</h4>
#             <ul>
#                 <li><a href="#">전국 기온 평년보다 높아... 완연한 봄날씨</a></li>
#                 <li><a href="#">국제 유가 하락세 지속, 국내 기름값 영향은?</a></li>
#                 <li><a href="#">신기술 적용된 차세대 전기차, 주행거리 20% 향상</a></li>
#             </ul>
#         </section>
#
#     </section>
#     </body>
# </html>
# Out:
# Overwriting ex2.html

# %%
# %%writefile /content/news.html
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#   <meta charset="UTF-8">
#   <title>현대차 무인소방로봇</title>
# </head>
# <body>
#
#   <header>
#     <h1>한국경제</h1>
#     <nav>
#       <a href="#">경제</a>
#       <a href="#">산업</a>
#       <a href="#">국제</a>
#       <a href="#">테크</a>
#     </nav>
#   </header>
#
#   <h2>정의선 "무인소방로봇 100대 투입"</h2>
#   <p>양길성 기자 | 2026.02.25 08:31</p>
#
#   <img src="https://img.hankyung.com/photo/202602/01.43405369.1.jpg" alt="무인소방로봇 시연 장면" width="300">
#   <p>무인소방로봇이 경기 남양주시에서 시연을 하고 있다.</p>
#
#   <p>
#     현대자동차그룹이 화재 진압용 무인소방로봇을 재난 현장에 투입한다.
#     올해 4대 기증을 시작으로 향후 전국에 100대까지 보급 규모를 늘린다.
#   </p>
#
#   <h3>800도 불길 뚫는 첨단 로봇</h3>
#   <p>
#     무인소방로봇은 방수포, 자체 분무 시스템, 카메라 등을 갖췄다.
#     섭씨 800도 고열에서도 장비 온도를 50~60도로 낮춘다.
#   </p>
#
#   <h3>정의선 "제조업 역량 총동원"</h3>
#   <p>
#     정 회장은 "자동차 회사로서 우리가 할 수 있는 건 다 해야겠다고 생각했다"고 말했다.
#     100대를 전국에 투입하는 것이 목표라고 밝혔다.
#   </p>
#
#   <p>양길성 기자 vertigo@hankyung.com</p>
#
#   <h3>관련 뉴스</h3>
#   <ul>
#     <li><a href="#">박민우 현대차 AVP본부장 "포티투닷·R&amp;D본부 시너지로 가치 증명해야"</a></li>
#     <li><a href="#">현대위아가 쿠키를?…경남 농가와 '도담샌드' 선보여</a></li>
#   </ul>
#
#   <footer>
#     <p>한국경제신문 | 서울시 중구 청파로 463</p>
#     <p>Copyright 1999-2026. 한경닷컴 All rights reserved.</p>
#   </footer>
#
# </body>
# </html>
# Out:
# Overwriting /content/news.html

# %% [markdown]
# #W3C Validator 유효성 검사를 꼭 시행할 것
#
# [W3C Markup Validation Service](https://validator.w3.org/)

# %%
# %%writefile /content/portfolio.html
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#   <meta charset="UTF-8">
#   <title>임소라 포트폴리오</title>
# </head>
# <body>
#
#   <header>
#     <h1>임소라의 포트폴리오</h1>
#     <nav>
#       <a href="#about">자기소개</a>
#       <a href="#career">경력</a>
#       <a href="#contact">연락처</a>
#     </nav>
#   </header>
#
#   <main>
#
#     <section id="about">
#       <h2>자기소개</h2>
#       <figure>
#         <img src="프로필.png" alt="프로필" width="150">
#         <figcaption>안녕하세요, 임소라입니다.</figcaption>
#       </figure>
#       <p>
#         웹 개발에 관심이 많은 비전공자 출신 개발자입니다.
#         한경 부트캠프 풀스택 과정을 수료 중이고,
#         현재 HTML, CSS, JavaScript를 공부하고 있습니다.
#       </p>
#     </section>
#
#     <section id="career">
#       <h2>경력 사항</h2>
#       <ul>
#         <li>
#           <h3>한경아카데미 X 토스뱅크 부트캠프 풀스택 과정</h3>
#           <p><time datetime="2026-01">2026년 1월</time> ~ 현재</p>
#           <p>HTML/CSS/JavaScript 및 Node.js 학습 중</p>
#         </li>
#       </ul>
#     </section>
#
#   </main>
#
#   <footer id="contact">
#     <h2>연락처</h2>
#     <address>
#       <p>이메일: <a href="mailto:flathfk@gmail.com">flathfk@gmail.com</a></p>
#       <p>GitHub: <a href="https://github.com/flathfk">github.com/flathfk</a></p>
#     </address>
#     <p>Copyright 2026. 임소라 All rights reserved.</p>
#   </footer>
#
# </body>
# </html>
# Out:
# Overwriting /content/portfolio.html
