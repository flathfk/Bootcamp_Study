# %% [markdown]
# <a href="https://colab.research.google.com/github/flathfk/Bootcamp_Study/blob/main/260304_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile TOSS.html
#
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#     <meta charset="UTF-8">
#     <title>토스뱅크</title>
#     <style>
#         * {
#             box-sizing: border-box;
#             margin: 0;
#             padding: 0;
#         }
#
#         body {
#             background-color: #f5f5f5;
#             display: flex;
#             flex-direction: column;
#             min-height: 100vh;
#             gap: 15px;
#             font-family: 'Apple SD Gothic Neo', 'Pretendard', sans-serif;
#         }
#
#         .container {
#             display: flex;
#             justify-content: space-between;
#             align-items: center;
#             padding: 0 40px;
#             background-color: white;
#             box-shadow: 0 2px 5px rgba(0,0,0,0.05);
#             width: 100%;
#             max-width: 1400px;
#             margin: 0 auto;
#         }
#
#         /* 헤더 */
#         .header-container {
#             height: 80px;
#             position: sticky;
#             top: 0;
#             z-index: 100;
#         }
#
#         .logo img {
#             height: 80px;
#             width: auto;
#             display: block;
#         }
#
#         .nav-menu {
#             display: flex;
#             gap: 30px;
#             list-style: none;
#         }
#
#         .nav-menu li a {
#             text-decoration: none;
#             color: #333;
#             font-weight: 500;
#             font-size: 15px;
#         }
#
#         .nav-menu li a:hover {
#             color: #0064FF;
#         }
#
#         .header-btn {
#             background: #0064FF;
#             color: white;
#             border: none;
#             padding: 10px 20px;
#             border-radius: 8px;
#             font-size: 14px;
#             font-weight: 600;
#             cursor: pointer;
#         }
#
#         /* 메인 */
#         .main-container {
#             flex-grow: 1;
#             align-items: stretch;
#             gap: 20px;
#             padding: 30px 40px;
#             max-width: 1400px;
#             margin: 0 auto;
#             width: 100%;
#         }
#
#         .main {
#             flex: 2;
#             border: 1px solid #eee;
#             border-radius: 16px;
#             padding: 40px;
#             background-color: #fff;
#         }
#
#         .main .banner {
#             background: linear-gradient(135deg, #0064FF 0%, #00C4FF 100%);
#             border-radius: 12px;
#             padding: 40px;
#             color: white;
#             margin-bottom: 30px;
#         }
#
#         .main .banner h2 {
#             font-size: 26px;
#             font-weight: 800;
#             margin-bottom: 10px;
#         }
#
#         .main .banner p {
#             font-size: 15px;
#             opacity: 0.85;
#             margin-bottom: 20px;
#         }
#
#         .main .banner button {
#             background: white;
#             color: #0064FF;
#             border: none;
#             padding: 10px 24px;
#             border-radius: 8px;
#             font-weight: 700;
#             cursor: pointer;
#         }
#
#         .product-grid {
#             display: flex;
#             gap: 16px;
#             flex-wrap: wrap;
#         }
#
#         .product-card {
#             flex: 1;
#             min-width: 140px;
#             border: 1px solid #eee;
#             border-radius: 12px;
#             padding: 20px;
#             text-align: center;
#             cursor: pointer;
#             transition: 0.2s;
#         }
#
#         .product-card:hover {
#             border-color: #0064FF;
#             box-shadow: 0 4px 12px rgba(0,100,255,0.1);
#         }
#
#         .product-card .icon {
#             font-size: 28px;
#             margin-bottom: 10px;
#         }
#
#         .product-card h4 {
#             font-size: 14px;
#             color: #333;
#             font-weight: 600;
#         }
#
#         .product-card p {
#             font-size: 12px;
#             color: #888;
#             margin-top: 4px;
#         }
#
#         .aside {
#             flex: 1;
#             border: 1px solid #eee;
#             border-radius: 16px;
#             padding: 24px;
#             background-color: #fff;
#             display: flex;
#             flex-direction: column;
#             gap: 16px;
#         }
#
#         .aside h3 {
#             font-size: 16px;
#             font-weight: 700;
#             color: #111;
#             margin-bottom: 4px;
#         }
#
#         .notice-item {
#             border-bottom: 1px solid #f0f0f0;
#             padding-bottom: 14px;
#         }
#
#         .notice-item:last-child {
#             border-bottom: none;
#         }
#
#         .notice-item .tag {
#             display: inline-block;
#             font-size: 11px;
#             background: #e8f0ff;
#             color: #0064FF;
#             padding: 2px 8px;
#             border-radius: 4px;
#             margin-bottom: 6px;
#             font-weight: 600;
#         }
#
#         .notice-item p {
#             font-size: 13px;
#             color: #333;
#             line-height: 1.5;
#         }
#
#         .notice-item span {
#             font-size: 11px;
#             color: #aaa;
#             margin-top: 4px;
#             display: block;
#         }
#
#         .rate-box {
#             background: #f8f9ff;
#             border-radius: 10px;
#             padding: 16px;
#             text-align: center;
#         }
#
#         .rate-box .label {
#             font-size: 12px;
#             color: #888;
#             margin-bottom: 4px;
#         }
#
#         .rate-box .rate {
#             font-size: 28px;
#             font-weight: 800;
#             color: #0064FF;
#         }
#
#         .rate-box .sub {
#             font-size: 12px;
#             color: #aaa;
#             margin-top: 2px;
#         }
#
#         /* 푸터 */
#         .footer-container {
#             height: auto;
#             padding: 40px;
#             gap: 40px;
#             align-items: flex-start;
#             background: #f8f8f8;
#         }
#
#         .footer-links {
#             display: flex;
#             gap: 16px;
#             margin-bottom: 16px;
#             flex-wrap: wrap;
#         }
#
#         .footer-links a {
#             font-size: 12px;
#             color: #888;
#             text-decoration: none;
#         }
#
#         .footer-links a:hover { color: #333; }
#         .footer-links a.bold { font-weight: 700; color: #333; }
#
#         .address, .as_center {
#             line-height: 1.6;
#             font-size: 14px;
#             color: #666;
#         }
#
#         .address strong, .as_center strong {
#             display: inline-block;
#             margin-bottom: 8px;
#             color: #333;
#             font-size: 16px;
#         }
#     </style>
# </head>
# <body>
#
#     <header class="header-container container">
#         <div class="logo">
#             <a href="#">
#                 <img src="logo.png" alt="서비스 로고">
#             </a>
#         </div>
#         <nav>
#             <ul class="nav-menu">
#                 <li><a href="#">통장</a></li>
#                 <li><a href="#">예금·적금</a></li>
#                 <li><a href="#">대출</a></li>
#                 <li><a href="#">외환</a></li>
#                 <li><a href="#">카드</a></li>
#                 <li><a href="#">고객센터</a></li>
#             </ul>
#         </nav>
#         <button class="header-btn">시작하기</button>
#     </header>
#
#     <main class="main-container container">
#         <article class="main">
#             <!-- 배너 -->
#             <div class="banner">
#                 <h2>알아서 챙겨주는<br>토스뱅크 통장</h2>
#                 <p>하루만 넣어도 이자가 쌓여요.<br>연 2.0% 매일 이자 지급</p>
#                 <button>지금 만들기</button>
#             </div>
#
#             <!-- 상품 카드 -->
#             <div class="product-grid">
#                 <div class="product-card">
#                     <div class="icon">🏦</div>
#                     <h4>통장</h4>
#                     <p>매일 이자 지급</p>
#                 </div>
#                 <div class="product-card">
#                     <div class="icon">💰</div>
#                     <h4>예금·적금</h4>
#                     <p>최대 연 4.0%</p>
#                 </div>
#                 <div class="product-card">
#                     <div class="icon">📋</div>
#                     <h4>대출</h4>
#                     <p>중도상환수수료<br>0원</p>
#                 </div>
#                 <div class="product-card">
#                     <div class="icon">💱</div>
#                     <h4>외환</h4>
#                     <p>평생 무료 환전</p>
#                 </div>
#                 <div class="product-card">
#                     <div class="icon">💳</div>
#                     <h4>카드</h4>
#                     <p>결제 시 즉시 할인</p>
#                 </div>
#             </div>
#         </article>
#
#         <aside class="aside">
#             <!-- 금리 박스 -->
#             <div class="rate-box">
#                 <div class="label">토스뱅크 통장 금리</div>
#                 <div class="rate">연 2.0%</div>
#                 <div class="sub">매일 자동 지급</div>
#             </div>
#
#             <h3>공지사항</h3>
#
#             <div class="notice-item">
#                 <span class="tag">공지</span>
#                 <p>토스뱅크 K-패스 카드 출시 안내</p>
#                 <span>2025.03.01</span>
#             </div>
#             <div class="notice-item">
#                 <span class="tag">이벤트</span>
#                 <p>모임통장 개설 시 최대 3만원 혜택</p>
#                 <span>2025.02.20</span>
#             </div>
#             <div class="notice-item">
#                 <span class="tag">공지</span>
#                 <p>외환 서비스 점검 안내 (3/10 02:00~04:00)</p>
#                 <span>2025.02.15</span>
#             </div>
#             <div class="notice-item">
#                 <span class="tag">이벤트</span>
#                 <p>첫 대출 고객 금리 우대 이벤트</p>
#                 <span>2025.02.10</span>
#             </div>
#         </aside>
#     </main>
#
#     <footer class="footer-container container">
#         <div class="address">
#             <div class="footer-links">
#                 <a href="#" class="bold">개인정보 처리방침</a>
#                 <a href="#">보호금융상품등록부</a>
#                 <a href="#">이용자유의사항</a>
#                 <a href="#">공지사항</a>
#                 <a href="#">경영공시</a>
#             </div>
#             <p><strong>토스뱅크</strong><br>
#                 사업자 등록번호 : 462-86-01671<br>
#                 주소 : 06133 서울특별시 강남구 테헤란로 131, 13층 (역삼동, 한국지식재산센터)<br>
#                 대표 : 이은미
#             </p>
#         </div>
#
#         <div class="as_center">
#             <p><strong>고객센터</strong><br>
#                 전화 : 1661-7654 (24시간 연중무휴)<br>
#                 해외전화 : +82-2-6975-9000<br>
#                 이메일 : help@tossbank.com
#             </p>
#         </div>
#     </footer>
#
# </body>
# </html>
# Out:
# Writing TOSS.html
