# %% [markdown]
# <a href="https://colab.research.google.com/github/flathfk/Bootcamp_Study/blob/main/260305_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🏦 Toss Bank Clone
#
# HTML / CSS / Express.js 로 구현한 토스뱅크 클론 사이트
# 웹개발 부트캠프 실습 프로젝트
#
# ## 페이지 구성
# - `/` 메인
# - `/about` 은행소개
# - `/deposit` 예금·적금
# - `/loan` 대출
# - `/card` 카드
# - `/support` 고객센터
#
# ## 실행 방법
# 1. npm install express
# 2. node server.js
# 3. http://localhost:3000

# %% [markdown]
# ---

# %%
# !pkill -f "node server.js"
# !nohup node server.js > server.log 2>&1 &
# !sleep 2 && tail -n 5 server.log
# Out:
# Server running on port 3000

# %% [markdown]
# ---
#
# 서버 죽이기

# %%
# !npm init -y
# !npm install express
# Out:
# Wrote to /content/package.json:
#
# {
#   "name": "content",
#   "version": "1.0.0",
#   "main": "index.js",
#   "scripts": {
#     "test": "echo \"Error: no test specified\" && exit 1",
#     "start": "node server.js"
#   },
#   "keywords": [],
#   "author": "",
#   "license": "ISC",
#   "dependencies": {
#     "express": "^5.2.1"
#   },
#   "devDependencies": {},
#   "description": ""
# }
#
#
#
# ⠙⠙⠹⠸⠼⠴
# up to date, audited 66 packages in 802ms
# ⠴
# ⠴22 packages are looking for funding
# ⠴  run `npm fund` for details
# ⠴
# found 0 vulnerabilities
# ⠴

# %%
# %%writefile server.js
#
# const express = require("express");
# const path = require("path");
# const app = express();
#
# app.get("/", (req, res) => {
#   res.sendFile(path.join(__dirname, "index.html"));
# });
#
# app.get("/about", (req, res) => {
#   res.sendFile(path.join(__dirname, "about.html"));
# });
#
# app.get("/deposit", (req, res) => {
#   res.sendFile(path.join(__dirname, "deposit.html"));
# });
#
# app.get("/loan", (req, res) => {
#   res.sendFile(path.join(__dirname, "loan.html"));
# });
#
# app.get("/card", (req, res) => {
#   res.sendFile(path.join(__dirname, "card.html"));
# });
#
# app.get("/support", (req, res) => {
#   res.sendFile(path.join(__dirname, "support.html"));
# });
#
# app.get("/logo.png", (req, res) => {
#   res.sendFile(path.join(__dirname, "logo.png"));
# });
#
# app.listen(3000, () => {
#   console.log("Server running on port 3000");
# });
# Out:
# Overwriting server.js

# %%
# %%writefile index.html
#
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#     <meta charset="UTF-8">
#     <title>토스뱅크</title>
#     <style>
#         * {
#             box-sizing: border-box;
#             margin: 0;
#             padding: 0;
#         }
#
#         body {
#             background-color: #f5f5f5;
#             display: flex;
#             flex-direction: column;
#             min-height: 100vh;
#             gap: 15px;
#             font-family: 'Apple SD Gothic Neo', 'Pretendard', sans-serif;
#         }
#
#         .container {
#             display: flex;
#             justify-content: space-between;
#             align-items: center;
#             padding: 0 40px;
#             background-color: white;
#             box-shadow: 0 2px 5px rgba(0,0,0,0.05);
#             width: 100%;
#             max-width: 1400px;
#             margin: 0 auto;
#         }
#
#         /* 헤더 */
#         .header-container {
#             height: 80px;
#             position: sticky;
#             top: 0;
#             z-index: 100;
#         }
#
#         .logo img {
#             height: 80px;
#             width: auto;
#             display: block;
#         }
#
#         .nav-menu {
#             display: flex;
#             gap: 30px;
#             list-style: none;
#         }
#
#         .nav-menu li a {
#             text-decoration: none;
#             color: #333;
#             font-weight: 500;
#             font-size: 15px;
#         }
#
#         .nav-menu li a:hover {
#             color: #0064FF;
#         }
#
#         .header-btn {
#             background: #0064FF;
#             color: white;
#             border: none;
#             padding: 10px 20px;
#             border-radius: 8px;
#             font-size: 14px;
#             font-weight: 600;
#             cursor: pointer;
#         }
#
#         /* 메인 */
#         .main-container {
#             flex-grow: 1;
#             align-items: stretch;
#             gap: 20px;
#             padding: 30px 40px;
#             max-width: 1400px;
#             margin: 0 auto;
#             width: 100%;
#         }
#
#         .main {
#             flex: 2;
#             border: 1px solid #eee;
#             border-radius: 16px;
#             padding: 40px;
#             background-color: #fff;
#         }
#
#         .main .banner {
#             background: linear-gradient(135deg, #0064FF 0%, #00C4FF 100%);
#             border-radius: 12px;
#             padding: 40px;
#             color: white;
#             margin-bottom: 30px;
#         }
#
#         .main .banner h2 {
#             font-size: 26px;
#             font-weight: 800;
#             margin-bottom: 10px;
#         }
#
#         .main .banner p {
#             font-size: 15px;
#             opacity: 0.85;
#             margin-bottom: 20px;
#         }
#
#         .main .banner button {
#             background: white;
#             color: #0064FF;
#             border: none;
#             padding: 10px 24px;
#             border-radius: 8px;
#             font-weight: 700;
#             cursor: pointer;
#         }
#
#         .product-grid {
#             display: flex;
#             gap: 16px;
#             flex-wrap: wrap;
#         }
#
#         .product-card {
#             flex: 1;
#             min-width: 140px;
#             border: 1px solid #eee;
#             border-radius: 12px;
#             padding: 20px;
#             text-align: center;
#             cursor: pointer;
#             transition: 0.2s;
#         }
#
#         .product-card:hover {
#             border-color: #0064FF;
#             box-shadow: 0 4px 12px rgba(0,100,255,0.1);
#         }
#
#         .product-card .icon {
#             font-size: 28px;
#             margin-bottom: 10px;
#         }
#
#         .product-card h4 {
#             font-size: 14px;
#             color: #333;
#             font-weight: 600;
#         }
#
#         .product-card p {
#             font-size: 12px;
#             color: #888;
#             margin-top: 4px;
#         }
#
#         .aside {
#             flex: 1;
#             border: 1px solid #eee;
#             border-radius: 16px;
#             padding: 24px;
#             background-color: #fff;
#             display: flex;
#             flex-direction: column;
#             gap: 16px;
#         }
#
#         .aside h3 {
#             font-size: 16px;
#             font-weight: 700;
#             color: #111;
#             margin-bottom: 4px;
#         }
#
#         .notice-item {
#             border-bottom: 1px solid #f0f0f0;
#             padding-bottom: 14px;
#         }
#
#         .notice-item:last-child {
#             border-bottom: none;
#         }
#
#         .notice-item .tag {
#             display: inline-block;
#             font-size: 11px;
#             background: #e8f0ff;
#             color: #0064FF;
#             padding: 2px 8px;
#             border-radius: 4px;
#             margin-bottom: 6px;
#             font-weight: 600;
#         }
#
#         .notice-item p {
#             font-size: 13px;
#             color: #333;
#             line-height: 1.5;
#         }
#
#         .notice-item span {
#             font-size: 11px;
#             color: #aaa;
#             margin-top: 4px;
#             display: block;
#         }
#
#         .rate-box {
#             background: #f8f9ff;
#             border-radius: 10px;
#             padding: 16px;
#             text-align: center;
#         }
#
#         .rate-box .label {
#             font-size: 12px;
#             color: #888;
#             margin-bottom: 4px;
#         }
#
#         .rate-box .rate {
#             font-size: 28px;
#             font-weight: 800;
#             color: #0064FF;
#         }
#
#         .rate-box .sub {
#             font-size: 12px;
#             color: #aaa;
#             margin-top: 2px;
#         }
#
#         /* 푸터 */
#         .footer-container {
#             height: auto;
#             padding: 40px;
#             gap: 40px;
#             align-items: flex-start;
#             background: #f8f8f8;
#         }
#
#         .footer-links {
#             display: flex;
#             gap: 16px;
#             margin-bottom: 16px;
#             flex-wrap: wrap;
#         }
#
#         .footer-links a {
#             font-size: 12px;
#             color: #888;
#             text-decoration: none;
#         }
#
#         .footer-links a:hover { color: #333; }
#         .footer-links a.bold { font-weight: 700; color: #333; }
#
#         .address, .as_center {
#             line-height: 1.6;
#             font-size: 14px;
#             color: #666;
#         }
#
#         .address strong, .as_center strong {
#             display: inline-block;
#             margin-bottom: 8px;
#             color: #333;
#             font-size: 16px;
#         }
#     </style>
# </head>
# <body>
#
#     <header class="header-container container">
#         <div class="logo">
#             <a href="#">
#                 <img src="logo.png" alt="서비스 로고">
#             </a>
#         </div>
#         <nav>
#             <ul class="nav-menu">
#                 <li><a href="/about">은행소개</a></li>
#                 <li><a href="/deposit">예금·적금</a></li>
#                 <li><a href="/loan">대출</a></li>
#                 <li><a href="/card">카드</a></li>
#                 <li><a href="/support">고객센터</a></li>
#             </ul>
#         </nav>
#         <button class="header-btn">시작하기</button>
#     </header>
#
#     <main class="main-container container">
#         <article class="main">
#             <!-- 배너 -->
#             <div class="banner">
#                 <h2>알아서 챙겨주는<br>토스뱅크 통장</h2>
#                 <p>하루만 넣어도 이자가 쌓여요.<br>연 2.0% 매일 이자 지급</p>
#                 <button>지금 만들기</button>
#             </div>
#
#             <!-- 상품 카드 -->
#             <div class="product-grid">
#                 <div class="product-card">
#                     <div class="icon">🏦</div>
#                     <h4>통장</h4>
#                     <p>매일 이자 지급</p>
#                 </div>
#                 <div class="product-card">
#                     <div class="icon">💰</div>
#                     <h4>예금·적금</h4>
#                     <p>최대 연 4.0%</p>
#                 </div>
#                 <div class="product-card">
#                     <div class="icon">📋</div>
#                     <h4>대출</h4>
#                     <p>중도상환수수료<br>0원</p>
#                 </div>
#                 <div class="product-card">
#                     <div class="icon">💱</div>
#                     <h4>외환</h4>
#                     <p>평생 무료 환전</p>
#                 </div>
#                 <div class="product-card">
#                     <div class="icon">💳</div>
#                     <h4>카드</h4>
#                     <p>결제 시 즉시 할인</p>
#                 </div>
#             </div>
#         </article>
#
#         <aside class="aside">
#             <!-- 금리 박스 -->
#             <div class="rate-box">
#                 <div class="label">토스뱅크 통장 금리</div>
#                 <div class="rate">연 2.0%</div>
#                 <div class="sub">매일 자동 지급</div>
#             </div>
#
#             <h3>공지사항</h3>
#
#             <div class="notice-item">
#                 <span class="tag">공지</span>
#                 <p>토스뱅크 K-패스 카드 출시 안내</p>
#                 <span>2025.03.01</span>
#             </div>
#             <div class="notice-item">
#                 <span class="tag">이벤트</span>
#                 <p>모임통장 개설 시 최대 3만원 혜택</p>
#                 <span>2025.02.20</span>
#             </div>
#             <div class="notice-item">
#                 <span class="tag">공지</span>
#                 <p>외환 서비스 점검 안내 (3/10 02:00~04:00)</p>
#                 <span>2025.02.15</span>
#             </div>
#             <div class="notice-item">
#                 <span class="tag">이벤트</span>
#                 <p>첫 대출 고객 금리 우대 이벤트</p>
#                 <span>2025.02.10</span>
#             </div>
#         </aside>
#     </main>
#
#     <footer class="footer-container container">
#         <div class="address">
#             <div class="footer-links">
#                 <a href="#" class="bold">개인정보 처리방침</a>
#                 <a href="#">보호금융상품등록부</a>
#                 <a href="#">이용자유의사항</a>
#                 <a href="#">공지사항</a>
#                 <a href="#">경영공시</a>
#             </div>
#             <p><strong>토스뱅크</strong><br>
#                 사업자 등록번호 : 462-86-01671<br>
#                 주소 : 06133 서울특별시 강남구 테헤란로 131, 13층 (역삼동, 한국지식재산센터)<br>
#                 대표 : 이은미
#             </p>
#         </div>
#
#         <div class="as_center">
#             <p><strong>고객센터</strong><br>
#                 전화 : 1661-7654 (24시간 연중무휴)<br>
#                 해외전화 : +82-2-6975-9000<br>
#                 이메일 : <a href="/cdn-cgi/l/email-protection" class="__cf_email__" data-cfemail="8de5e8e1
# Out:
# Overwriting index.html

# %%
# %%writefile about.html
#
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#     <meta charset="UTF-8">
#     <title>은행소개 - 토스뱅크</title>
#     <style>
#         * { box-sizing: border-box; margin: 0; padding: 0; }
#
#         body {
#             background-color: #f5f5f5;
#             display: flex;
#             flex-direction: column;
#             min-height: 100vh;
#             gap: 15px;
#             font-family: 'Apple SD Gothic Neo', 'Pretendard', sans-serif;
#         }
#
#         .container {
#             display: flex;
#             justify-content: space-between;
#             align-items: center;
#             padding: 0 40px;
#             background-color: white;
#             box-shadow: 0 2px 5px rgba(0,0,0,0.05);
#             width: 100%;
#             max-width: 1400px;
#             margin: 0 auto;
#         }
#
#         .header-container {
#             height: 80px;
#             position: sticky;
#             top: 0;
#             z-index: 100;
#         }
#
#         .logo img { height: 80px; width: auto; display: block; }
#
#         .nav-menu { display: flex; gap: 30px; list-style: none; }
#         .nav-menu li a {
#             text-decoration: none;
#             color: #333;
#             font-weight: 500;
#             font-size: 15px;
#         }
#         .nav-menu li a:hover { color: #0064FF; }
#         .nav-menu li a.active { color: #0064FF; font-weight: 700; }
#
#         .header-btn {
#             background: #0064FF;
#             color: white;
#             border: none;
#             padding: 10px 20px;
#             border-radius: 8px;
#             font-size: 14px;
#             font-weight: 600;
#             cursor: pointer;
#         }
#
#         /* 페이지 공통 */
#         .page-wrap {
#             max-width: 1400px;
#             margin: 0 auto;
#             width: 100%;
#             padding: 40px 40px;
#             flex-grow: 1;
#         }
#
#         /* 히어로 */
#         .hero {
#             background: linear-gradient(135deg, #1a1a2e 0%, #16213e 100%);
#             border-radius: 20px;
#             padding: 80px 60px;
#             color: white;
#             margin-bottom: 40px;
#         }
#         .hero p.eyebrow {
#             font-size: 13px;
#             letter-spacing: 2px;
#             color: #00C4FF;
#             margin-bottom: 16px;
#             text-transform: uppercase;
#         }
#         .hero h1 { font-size: 40px; font-weight: 900; line-height: 1.3; margin-bottom: 20px; }
#         .hero p.desc { font-size: 16px; color: rgba(255,255,255,0.7); line-height: 1.7; }
#
#         /* 수치 */
#         .stats {
#             display: flex;
#             gap: 20px;
#             margin-bottom: 40px;
#         }
#         .stat-card {
#             flex: 1;
#             background: white;
#             border-radius: 16px;
#             padding: 30px;
#             text-align: center;
#             border: 1px solid #eee;
#         }
#         .stat-card .num {
#             font-size: 36px;
#             font-weight: 900;
#             color: #0064FF;
#             margin-bottom: 8px;
#         }
#         .stat-card .label { font-size: 13px; color: #888; }
#
#         /* 소개 섹션 */
#         .intro-section {
#             background: white;
#             border-radius: 16px;
#             padding: 40px;
#             border: 1px solid #eee;
#             margin-bottom: 20px;
#         }
#         .intro-section h2 { font-size: 22px; font-weight: 800; margin-bottom: 20px; color: #111; }
#
#         .intro-list { display: flex; flex-direction: column; gap: 16px; }
#         .intro-item {
#             display: flex;
#             gap: 16px;
#             align-items: flex-start;
#             padding: 20px;
#             background: #f8f9ff;
#             border-radius: 12px;
#         }
#         .intro-item .num-badge {
#             min-width: 32px;
#             height: 32px;
#             background: #0064FF;
#             color: white;
#             border-radius: 50%;
#             display: flex;
#             align-items: center;
#             justify-content: center;
#             font-size: 14px;
#             font-weight: 700;
#         }
#         .intro-item h4 { font-size: 15px; font-weight: 700; margin-bottom: 4px; color: #111; }
#         .intro-item p { font-size: 13px; color: #666; line-height: 1.6; }
#
#         /* 푸터 */
#         .footer-container {
#             height: auto;
#             padding: 40px;
#             gap: 40px;
#             align-items: flex-start;
#             background: #f8f8f8;
#         }
#         .footer-links { display: flex; gap: 16px; margin-bottom: 16px; flex-wrap: wrap; }
#         .footer-links a { font-size: 12px; color: #888; text-decoration: none; }
#         .footer-links a:hover { color: #333; }
#         .footer-links a.bold { font-weight: 700; color: #333; }
#         .address, .as_center { line-height: 1.6; font-size: 14px; color: #666; }
#         .address strong, .as_center strong {
#             display: inline-block;
#             margin-bottom: 8px;
#             color: #333;
#             font-size: 16px;
#         }
#     </style>
# </head>
# <body>
#
#     <header class="header-container container">
#         <div class="logo">
#             <a href="/">
#                 <img src="logo.png" alt="서비스 로고">
#             </a>
#         </div>
#         <nav>
#             <ul class="nav-menu">
#                 <li><a href="/about" class="active">은행소개</a></li>
#                 <li><a href="/deposit">예금·적금</a></li>
#                 <li><a href="/loan">대출</a></li>
#                 <li><a href="/card">카드</a></li>
#                 <li><a href="/support">고객센터</a></li>
#             </ul>
#         </nav>
#         <button class="header-btn">시작하기</button>
#     </header>
#
#     <div class="page-wrap">
#
#         <section class="hero">
#             <p class="eyebrow">About Toss Bank</p>
#             <h1>은행을 바꾸는 은행,<br>토스뱅크</h1>
#             <p class="desc">토스뱅크는 대한민국 최초의 인터넷전문은행 중 하나로,<br>
#             모든 금융 서비스를 더 쉽고, 더 공정하게 만들어갑니다.</p>
#         </section>
#
#         <div class="stats">
#             <div class="stat-card">
#                 <div class="num">900만+</div>
#                 <div class="label">누적 고객 수</div>
#             </div>
#             <div class="stat-card">
#                 <div class="num">24시간</div>
#                 <div class="label">연중무휴 고객센터</div>
#             </div>
#             <div class="stat-card">
#                 <div class="num">제1금융권</div>
#                 <div class="label">인가 은행</div>
#             </div>
#             <div class="stat-card">
#                 <div class="num">2021년</div>
#                 <div class="label">서비스 출시</div>
#             </div>
#         </div>
#
#         <div class="intro-section">
#             <h2>토스뱅크가 다른 이유</h2>
#             <div class="intro-list">
#                 <div class="intro-item">
#                     <div class="num-badge">1</div>
#                     <div>
#                         <h4>중도상환수수료 0원</h4>
#                         <p>대출을 일찍 갚아도 추가 비용이 없어요. 고객 편의를 최우선으로 생각합니다.</p>
#                     </div>
#                 </div>
#                 <div class="intro-item">
#                     <div class="num-badge">2</div>
#                     <div>
#                         <h4>매일 이자 지급</h4>
#                         <p>하루만 맡겨도 이자가 쌓여요. 통장에 돈이 있는 매 순간 이자가 붙습니다.</p>
#                     </div>
#                 </div>
#                 <div class="intro-item">
#                     <div class="num-badge">3</div>
#                     <div>
#                         <h4>평생 무료 환전</h4>
#                         <p>외화를 사고 팔 때 수수료가 없어요. 해외여행, 해외결제 모두 무료입니다.</p>
#                     </div>
#                 </div>
#                 <div class="intro-item">
#                     <div class="num-badge">4</div>
#                     <div>
#                         <h4>완전한 비대면 서비스</h4>
#                         <p>지점 방문 없이 앱 하나로 모든 금융 업무를 처리할 수 있어요.</p>
#                     </div>
#                 </div>
#             </div>
#         </div>
#
#     </div>
#
#     <footer class="footer-container container">
#         <div class="address">
#             <div class="footer-links">
#                 <a href="#" class="bold">개인정보 처리방침</a>
#                 <a href="#">보호금융상품등록부</a>
#                 <a href="#">이용자유의사항</a>
#                 <a href="#">공지사항</a>
#                 <a href="#">경영공시</a>
#             </div>
#             <p><strong>토스뱅크</strong><br>
#                 사업자 등록번호 : 462-86-01671<br>
#                 주소 : 06133 서울특별시 강남구 테헤란로 131, 13층 (역삼동, 한국지식재산센터)<br>
#                 대표 : 이은미
#             </p>
#         </div>
#         <div class="as_center">
#             <p><strong>고객센터</strong><br>
#                 전화 : 1661-7654 (24시간 연중무휴)<br>
#                 해외전화 : +82-2-6975-9000<br>
#                 이메일 : <a href="/cdn-cgi/l/email-protection" class="__cf_email__" data-cfemail="f79f929b
# Out:
# Overwriting about.html

# %%
# %%writefile deposit.html
#
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#     <meta charset="UTF-8">
#     <title>예금·적금 - 토스뱅크</title>
#     <style>
#         * { box-sizing: border-box; margin: 0; padding: 0; }
#
#         body {
#             background-color: #f5f5f5;
#             display: flex;
#             flex-direction: column;
#             min-height: 100vh;
#             gap: 15px;
#             font-family: 'Apple SD Gothic Neo', 'Pretendard', sans-serif;
#         }
#
#         .container {
#             display: flex;
#             justify-content: space-between;
#             align-items: center;
#             padding: 0 40px;
#             background-color: white;
#             box-shadow: 0 2px 5px rgba(0,0,0,0.05);
#             width: 100%;
#             max-width: 1400px;
#             margin: 0 auto;
#         }
#
#         .header-container { height: 80px; position: sticky; top: 0; z-index: 100; }
#         .logo img { height: 80px; width: auto; display: block; }
#         .nav-menu { display: flex; gap: 30px; list-style: none; }
#         .nav-menu li a { text-decoration: none; color: #333; font-weight: 500; font-size: 15px; }
#         .nav-menu li a:hover { color: #0064FF; }
#         .nav-menu li a.active { color: #0064FF; font-weight: 700; }
#         .header-btn {
#             background: #0064FF; color: white; border: none;
#             padding: 10px 20px; border-radius: 8px;
#             font-size: 14px; font-weight: 600; cursor: pointer;
#         }
#
#         .page-wrap {
#             max-width: 1400px;
#             margin: 0 auto;
#             width: 100%;
#             padding: 40px;
#             flex-grow: 1;
#         }
#
#         .hero {
#             background: linear-gradient(135deg, #0064FF 0%, #00C4FF 100%);
#             border-radius: 20px;
#             padding: 70px 60px;
#             color: white;
#             margin-bottom: 40px;
#         }
#         .hero p.eyebrow { font-size: 13px; letter-spacing: 2px; color: rgba(255,255,255,0.7); margin-bottom: 16px; }
#         .hero h1 { font-size: 38px; font-weight: 900; line-height: 1.3; margin-bottom: 16px; }
#         .hero p.desc { font-size: 15px; color: rgba(255,255,255,0.85); line-height: 1.7; }
#
#         /* 탭 */
#         .tab-wrap { display: flex; gap: 8px; margin-bottom: 24px; }
#         .tab-btn {
#             padding: 10px 24px;
#             border-radius: 20px;
#             border: 1px solid #ddd;
#             background: white;
#             font-size: 14px;
#             font-weight: 600;
#             cursor: pointer;
#             color: #666;
#         }
#         .tab-btn.on { background: #0064FF; color: white; border-color: #0064FF; }
#
#         /* 상품 카드 그리드 */
#         .product-grid { display: flex; gap: 20px; flex-wrap: wrap; }
#
#         .product-card {
#             flex: 1;
#             min-width: 280px;
#             background: white;
#             border: 1px solid #eee;
#             border-radius: 16px;
#             padding: 28px;
#         }
#
#         .product-card .badge {
#             display: inline-block;
#             font-size: 11px;
#             background: #e8f0ff;
#             color: #0064FF;
#             padding: 3px 10px;
#             border-radius: 4px;
#             font-weight: 700;
#             margin-bottom: 14px;
#         }
#
#         .product-card h3 { font-size: 18px; font-weight: 800; margin-bottom: 8px; color: #111; }
#         .product-card p { font-size: 13px; color: #888; line-height: 1.6; margin-bottom: 20px; }
#
#         .product-card .rate-row {
#             display: flex;
#             align-items: baseline;
#             gap: 6px;
#             margin-bottom: 20px;
#         }
#         .product-card .rate-num { font-size: 32px; font-weight: 900; color: #0064FF; }
#         .product-card .rate-unit { font-size: 14px; color: #888; }
#
#         .product-card button {
#             width: 100%;
#             padding: 12px;
#             background: #0064FF;
#             color: white;
#             border: none;
#             border-radius: 10px;
#             font-size: 14px;
#             font-weight: 700;
#             cursor: pointer;
#         }
#
#         .product-card.secondary button { background: #f0f4ff; color: #0064FF; }
#
#         /* 안내 */
#         .notice-box {
#             background: white;
#             border: 1px solid #eee;
#             border-radius: 16px;
#             padding: 24px 28px;
#             margin-top: 20px;
#             font-size: 12px;
#             color: #aaa;
#             line-height: 1.8;
#         }
#
#         /* 푸터 */
#         .footer-container { height: auto; padding: 40px; gap: 40px; align-items: flex-start; background: #f8f8f8; }
#         .footer-links { display: flex; gap: 16px; margin-bottom: 16px; flex-wrap: wrap; }
#         .footer-links a { font-size: 12px; color: #888; text-decoration: none; }
#         .footer-links a:hover { color: #333; }
#         .footer-links a.bold { font-weight: 700; color: #333; }
#         .address, .as_center { line-height: 1.6; font-size: 14px; color: #666; }
#         .address strong, .as_center strong { display: inline-block; margin-bottom: 8px; color: #333; font-size: 16px; }
#     </style>
# </head>
# <body>
#
#     <header class="header-container container">
#         <div class="logo">
#             <a href="/"><img src="logo.png" alt="서비스 로고"></a>
#         </div>
#         <nav>
#             <ul class="nav-menu">
#                 <li><a href="/about">은행소개</a></li>
#                 <li><a href="/deposit" class="active">예금·적금</a></li>
#                 <li><a href="/loan">대출</a></li>
#                 <li><a href="/card">카드</a></li>
#                 <li><a href="/support">고객센터</a></li>
#             </ul>
#         </nav>
#         <button class="header-btn">시작하기</button>
#     </header>
#
#     <div class="page-wrap">
#
#         <section class="hero">
#             <p class="eyebrow">Deposit & Savings</p>
#             <h1>맡기는 순간부터<br>바로 이자가 붙어요</h1>
#             <p class="desc">예금은 가입 즉시 이자 입금, 적금은 급할 때 미리 뺄 수 있어요.</p>
#         </section>
#
#         <div class="tab-wrap">
#             <button class="tab-btn on">전체</button>
#             <button class="tab-btn">예금</button>
#             <button class="tab-btn">적금</button>
#         </div>
#
#         <div class="product-grid">
#             <div class="product-card">
#                 <span class="badge">예금</span>
#                 <h3>토스뱅크 정기예금</h3>
#                 <p>가입하는 순간 이자를 먼저 드려요.<br>만기 전 해지해도 우대 금리 유지.</p>
#                 <div class="rate-row">
#                     <span class="rate-num">연 3.5%</span>
#                     <span class="rate-unit">12개월 기준</span>
#                 </div>
#                 <button>지금 가입하기</button>
#             </div>
#
#             <div class="product-card secondary">
#                 <span class="badge">적금</span>
#                 <h3>먼저 받는 적금</h3>
#                 <p>매달 자유롭게 납입하고,<br>급할 땐 미리 출금도 가능해요.</p>
#                 <div class="rate-row">
#                     <span class="rate-num">연 4.0%</span>
#                     <span class="rate-unit">12개월 기준</span>
#                 </div>
#                 <button>지금 가입하기</button>
#             </div>
#
#             <div class="product-card secondary">
#                 <span class="badge">적금</span>
#                 <h3>모으기 적금</h3>
#                 <p>소액부터 시작해서 꾸준히 모아요.<br>자동이체 설정으로 편하게 납입.</p>
#                 <div class="rate-row">
#                     <span class="rate-num">연 3.8%</span>
#                     <span class="rate-unit">6개월 기준</span>
#                 </div>
#                 <button>지금 가입하기</button>
#             </div>
#         </div>
#
#         <div class="notice-box">
#             ※ 위 금리는 세전 기준이며, 시장 상황에 따라 변동될 수 있습니다.<br>
#             ※ 예금자보호법에 따라 원금과 이자를 합산하여 1인당 최고 5천만원까지 보호됩니다.
#         </div>
#
#     </div>
#
#     <footer class="footer-container container">
#         <div class="address">
#             <div class="footer-links">
#                 <a href="#" class="bold">개인정보 처리방침</a>
#                 <a href="#">보호금융상품등록부</a>
#                 <a href="#">이용자유의사항</a>
#                 <a href="#">공지사항</a>
#                 <a href="#">경영공시</a>
#             </div>
#             <p><strong>토스뱅크</strong><br>
#                 사업자 등록번호 : 462-86-01671<br>
#                 주소 : 06133 서울특별시 강남구 테헤란로 131, 13층 (역삼동, 한국지식재산센터)<br>
#                 대표 : 이은미
#             </p>
#         </div>
#         <div class="as_center">
#             <p><strong>고객센터</strong><br>
#                 전화 : 1661-7654 (24시간 연중무휴)<br>
#                 해외전화 : +82-2-6975-9000<br>
#                 이메일 : <a href="/cdn-cgi/l/email-protection" class="__cf_email__" data-cfemail="b7dfd2db
# Out:
# Overwriting deposit.html

# %%
# %%writefile loan.html
#
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#     <meta charset="UTF-8">
#     <title>대출 - 토스뱅크</title>
#     <style>
#         * { box-sizing: border-box; margin: 0; padding: 0; }
#
#         body {
#             background-color: #f5f5f5;
#             display: flex;
#             flex-direction: column;
#             min-height: 100vh;
#             gap: 15px;
#             font-family: 'Apple SD Gothic Neo', 'Pretendard', sans-serif;
#         }
#
#         .container {
#             display: flex;
#             justify-content: space-between;
#             align-items: center;
#             padding: 0 40px;
#             background-color: white;
#             box-shadow: 0 2px 5px rgba(0,0,0,0.05);
#             width: 100%;
#             max-width: 1400px;
#             margin: 0 auto;
#         }
#
#         .header-container { height: 80px; position: sticky; top: 0; z-index: 100; }
#         .logo img { height: 80px; width: auto; display: block; }
#         .nav-menu { display: flex; gap: 30px; list-style: none; }
#         .nav-menu li a { text-decoration: none; color: #333; font-weight: 500; font-size: 15px; }
#         .nav-menu li a:hover { color: #0064FF; }
#         .nav-menu li a.active { color: #0064FF; font-weight: 700; }
#         .header-btn {
#             background: #0064FF; color: white; border: none;
#             padding: 10px 20px; border-radius: 8px;
#             font-size: 14px; font-weight: 600; cursor: pointer;
#         }
#
#         .page-wrap { max-width: 1400px; margin: 0 auto; width: 100%; padding: 40px; flex-grow: 1; }
#
#         .hero {
#             background: linear-gradient(135deg, #1c1c3a 0%, #2d2d6b 100%);
#             border-radius: 20px;
#             padding: 70px 60px;
#             color: white;
#             margin-bottom: 40px;
#             position: relative;
#             overflow: hidden;
#         }
#         .hero::after {
#             content: '0원';
#             position: absolute;
#             right: 60px;
#             bottom: 30px;
#             font-size: 120px;
#             font-weight: 900;
#             color: rgba(255,255,255,0.05);
#         }
#         .hero p.eyebrow { font-size: 13px; letter-spacing: 2px; color: #8888ff; margin-bottom: 16px; }
#         .hero h1 { font-size: 38px; font-weight: 900; line-height: 1.3; margin-bottom: 16px; }
#         .hero p.desc { font-size: 15px; color: rgba(255,255,255,0.8); line-height: 1.7; }
#         .hero .tag-row { display: flex; gap: 10px; margin-top: 24px; }
#         .hero .tag-row span {
#             background: rgba(255,255,255,0.15);
#             color: white;
#             font-size: 12px;
#             padding: 6px 14px;
#             border-radius: 20px;
#             font-weight: 600;
#         }
#
#         /* 혜택 포인트 */
#         .benefit-grid { display: flex; gap: 20px; margin-bottom: 30px; }
#         .benefit-card {
#             flex: 1;
#             background: white;
#             border-radius: 16px;
#             padding: 28px;
#             border: 1px solid #eee;
#             text-align: center;
#         }
#         .benefit-card .icon { font-size: 32px; margin-bottom: 12px; }
#         .benefit-card h4 { font-size: 15px; font-weight: 800; margin-bottom: 6px; color: #111; }
#         .benefit-card p { font-size: 13px; color: #888; line-height: 1.5; }
#
#         /* 대출 상품 */
#         .loan-list { display: flex; flex-direction: column; gap: 16px; }
#         .loan-item {
#             background: white;
#             border: 1px solid #eee;
#             border-radius: 16px;
#             padding: 28px 32px;
#             display: flex;
#             justify-content: space-between;
#             align-items: center;
#         }
#         .loan-item .info h3 { font-size: 17px; font-weight: 800; margin-bottom: 6px; color: #111; }
#         .loan-item .info p { font-size: 13px; color: #888; }
#         .loan-item .right { text-align: right; }
#         .loan-item .right .rate { font-size: 22px; font-weight: 900; color: #0064FF; }
#         .loan-item .right .rate-label { font-size: 12px; color: #aaa; margin-bottom: 10px; }
#         .loan-item .right button {
#             background: #0064FF;
#             color: white;
#             border: none;
#             padding: 10px 20px;
#             border-radius: 8px;
#             font-size: 13px;
#             font-weight: 700;
#             cursor: pointer;
#         }
#
#         .notice-box {
#             background: white;
#             border: 1px solid #eee;
#             border-radius: 16px;
#             padding: 24px 28px;
#             margin-top: 20px;
#             font-size: 12px;
#             color: #aaa;
#             line-height: 1.8;
#         }
#
#         /* 푸터 */
#         .footer-container { height: auto; padding: 40px; gap: 40px; align-items: flex-start; background: #f8f8f8; }
#         .footer-links { display: flex; gap: 16px; margin-bottom: 16px; flex-wrap: wrap; }
#         .footer-links a { font-size: 12px; color: #888; text-decoration: none; }
#         .footer-links a:hover { color: #333; }
#         .footer-links a.bold { font-weight: 700; color: #333; }
#         .address, .as_center { line-height: 1.6; font-size: 14px; color: #666; }
#         .address strong, .as_center strong { display: inline-block; margin-bottom: 8px; color: #333; font-size: 16px; }
#     </style>
# </head>
# <body>
#
#     <header class="header-container container">
#         <div class="logo">
#             <a href="/"><img src="logo.png" alt="서비스 로고"></a>
#         </div>
#         <nav>
#             <ul class="nav-menu">
#                 <li><a href="/about">은행소개</a></li>
#                 <li><a href="/deposit">예금·적금</a></li>
#                 <li><a href="/loan" class="active">대출</a></li>
#                 <li><a href="/card">카드</a></li>
#                 <li><a href="/support">고객센터</a></li>
#             </ul>
#         </nav>
#         <button class="header-btn">시작하기</button>
#     </header>
#
#     <div class="page-wrap">
#
#         <section class="hero">
#             <p class="eyebrow">Loan</p>
#             <h1>쉽고 간편하게,<br>빌리고 갚는 대출</h1>
#             <p class="desc">중도상환수수료 없이 언제든 미리 갚을 수 있어요.</p>
#             <div class="tag-row">
#                 <span>중도상환수수료 0원</span>
#                 <span>비대면 3분 신청</span>
#                 <span>갈아타기 지원</span>
#             </div>
#         </section>
#
#         <div class="benefit-grid">
#             <div class="benefit-card">
#                 <div class="icon">💸</div>
#                 <h4>중도상환수수료 0원</h4>
#                 <p>언제든 미리 갚아도<br>추가 비용이 없어요.</p>
#             </div>
#             <div class="benefit-card">
#                 <div class="icon">⏱</div>
#                 <h4>3분 만에 신청 완료</h4>
#                 <p>공인인증서 없이<br>앱에서 바로 신청.</p>
#             </div>
#             <div class="benefit-card">
#                 <div class="icon">🔄</div>
#                 <h4>대출 갈아타기</h4>
#                 <p>타 은행 고금리 대출을<br>낮은 금리로 갈아타요.</p>
#             </div>
#             <div class="benefit-card">
#                 <div class="icon">📱</div>
#                 <h4>한도 즉시 조회</h4>
#                 <p>신용점수 영향 없이<br>한도 먼저 확인해요.</p>
#             </div>
#         </div>
#
#         <div class="loan-list">
#             <div class="loan-item">
#                 <div class="info">
#                     <h3>토스뱅크 신용대출</h3>
#                     <p>최대 1억원 · 최대 5년 · 비대면 신청</p>
#                 </div>
#                 <div class="right">
#                     <div class="rate-label">최저 금리</div>
#                     <div class="rate">연 4.9%~</div>
#                     <button>한도 조회하기</button>
#                 </div>
#             </div>
#             <div class="loan-item">
#                 <div class="info">
#                     <h3>토스뱅크 마이너스통장</h3>
#                     <p>최대 3천만원 · 쓴 만큼만 이자 납부</p>
#                 </div>
#                 <div class="right">
#                     <div class="rate-label">최저 금리</div>
#                     <div class="rate">연 5.5%~</div>
#                     <button>한도 조회하기</button>
#                 </div>
#             </div>
#             <div class="loan-item">
#                 <div class="info">
#                     <h3>대출 갈아타기</h3>
#                     <p>타 금융기관 대출을 더 낮은 금리로</p>
#                 </div>
#                 <div class="right">
#                     <div class="rate-label">최대 절감</div>
#                     <div class="rate">연 2% 이상</div>
#                     <button>갈아타기 신청</button>
#                 </div>
#             </div>
#         </div>
#
#         <div class="notice-box">
#             ※ 대출 금리는 신용도에 따라 달라질 수 있으며, 상기 금리는 최저 기준입니다.<br>
#             ※ 대출 전 금리, 상환 방법 등 조건을 꼼꼼히 확인하시기 바랍니다.<br>
#             ※ 과도한 부채는 신용등급 하락의 원인이 될 수 있습니다.
#         </div>
#
#     </div>
#
#     <footer class="footer-container container">
#         <div class="address">
#             <div class="footer-links">
#                 <a href="#" class="bold">개인정보 처리방침</a>
#                 <a href="#">보호금융상품등록부</a>
#                 <a href="#">이용자유의사항</a>
#                 <a href="#">공지사항</a>
#                 <a href="#">경영공시</a>
#             </div>
#             <p><strong>토스뱅크</strong><br>
#                 사업자 등록번호 : 462-86-01671<br>
#                 주소 : 06133 서울특별시 강남구 테헤란로 131, 13층 (역삼동, 한국지식재산센터)<br>
#                 대표 : 이은미
#             </p>
#         </div>
#         <div class="as_center">
#             <p><strong>고객센터</strong><br>
#                 전화 : 1661-7654 (24시간 연중무휴)<br>
#                 해외전화 : +82-2-6975-9000<br>
#                 이메일 : <a href="/cdn-cgi/l/email-protection" class="__cf_email__" data-cfemail="7d151811
# Out:
# Overwriting loan.html

# %%
# %%writefile card.html
#
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#     <meta charset="UTF-8">
#     <title>카드 - 토스뱅크</title>
#     <style>
#         * { box-sizing: border-box; margin: 0; padding: 0; }
#
#         body {
#             background-color: #f5f5f5;
#             display: flex;
#             flex-direction: column;
#             min-height: 100vh;
#             gap: 15px;
#             font-family: 'Apple SD Gothic Neo', 'Pretendard', sans-serif;
#         }
#
#         .container {
#             display: flex;
#             justify-content: space-between;
#             align-items: center;
#             padding: 0 40px;
#             background-color: white;
#             box-shadow: 0 2px 5px rgba(0,0,0,0.05);
#             width: 100%;
#             max-width: 1400px;
#             margin: 0 auto;
#         }
#
#         .header-container { height: 80px; position: sticky; top: 0; z-index: 100; }
#         .logo img { height: 80px; width: auto; display: block; }
#         .nav-menu { display: flex; gap: 30px; list-style: none; }
#         .nav-menu li a { text-decoration: none; color: #333; font-weight: 500; font-size: 15px; }
#         .nav-menu li a:hover { color: #0064FF; }
#         .nav-menu li a.active { color: #0064FF; font-weight: 700; }
#         .header-btn {
#             background: #0064FF; color: white; border: none;
#             padding: 10px 20px; border-radius: 8px;
#             font-size: 14px; font-weight: 600; cursor: pointer;
#         }
#
#         .page-wrap { max-width: 1400px; margin: 0 auto; width: 100%; padding: 40px; flex-grow: 1; }
#
#         .hero {
#             background: linear-gradient(135deg, #0f0f0f 0%, #1a1a1a 100%);
#             border-radius: 20px;
#             padding: 70px 60px;
#             color: white;
#             margin-bottom: 40px;
#         }
#         .hero p.eyebrow { font-size: 13px; letter-spacing: 2px; color: #888; margin-bottom: 16px; }
#         .hero h1 { font-size: 38px; font-weight: 900; line-height: 1.3; margin-bottom: 16px; }
#         .hero p.desc { font-size: 15px; color: rgba(255,255,255,0.7); line-height: 1.7; }
#
#         /* 카드 섹션 */
#         .section-title { font-size: 20px; font-weight: 800; color: #111; margin-bottom: 20px; }
#
#         .card-grid { display: flex; gap: 24px; margin-bottom: 40px; flex-wrap: wrap; }
#
#         .card-item {
#             flex: 1;
#             min-width: 260px;
#             background: white;
#             border: 1px solid #eee;
#             border-radius: 20px;
#             padding: 32px;
#             display: flex;
#             flex-direction: column;
#             gap: 16px;
#         }
#
#         /* 카드 시각화 */
#         .card-visual {
#             height: 140px;
#             border-radius: 14px;
#             display: flex;
#             flex-direction: column;
#             justify-content: space-between;
#             padding: 20px;
#             color: white;
#             font-weight: 600;
#             font-size: 13px;
#         }
#         .card-visual.blue { background: linear-gradient(135deg, #0064FF, #00C4FF); }
#         .card-visual.black { background: linear-gradient(135deg, #1a1a1a, #444); }
#         .card-visual.coral { background: linear-gradient(135deg, #FF6B35, #FF9A56); }
#
#         .card-visual .card-chip { width: 28px; height: 20px; background: rgba(255,255,255,0.4); border-radius: 4px; }
#         .card-visual .card-num { font-size: 12px; letter-spacing: 2px; opacity: 0.8; }
#
#         .card-item h3 { font-size: 16px; font-weight: 800; color: #111; }
#         .card-item p { font-size: 13px; color: #888; line-height: 1.5; }
#
#         .card-item .benefit-tags { display: flex; gap: 6px; flex-wrap: wrap; }
#         .card-item .benefit-tags span {
#             font-size: 11px;
#             background: #f0f4ff;
#             color: #0064FF;
#             padding: 4px 10px;
#             border-radius: 4px;
#             font-weight: 600;
#         }
#
#         .card-item button {
#             width: 100%;
#             padding: 12px;
#             background: #0064FF;
#             color: white;
#             border: none;
#             border-radius: 10px;
#             font-size: 14px;
#             font-weight: 700;
#             cursor: pointer;
#             margin-top: auto;
#         }
#
#         /* K패스 배너 */
#         .kpass-banner {
#             background: linear-gradient(135deg, #4C4CFF 0%, #0064FF 100%);
#             border-radius: 16px;
#             padding: 32px 40px;
#             color: white;
#             display: flex;
#             justify-content: space-between;
#             align-items: center;
#             margin-bottom: 20px;
#         }
#         .kpass-banner h3 { font-size: 20px; font-weight: 900; margin-bottom: 6px; }
#         .kpass-banner p { font-size: 14px; opacity: 0.85; }
#         .kpass-banner button {
#             background: white;
#             color: #0064FF;
#             border: none;
#             padding: 12px 24px;
#             border-radius: 10px;
#             font-weight: 700;
#             cursor: pointer;
#             white-space: nowrap;
#         }
#
#         /* 푸터 */
#         .footer-container { height: auto; padding: 40px; gap: 40px; align-items: flex-start; background: #f8f8f8; }
#         .footer-links { display: flex; gap: 16px; margin-bottom: 16px; flex-wrap: wrap; }
#         .footer-links a { font-size: 12px; color: #888; text-decoration: none; }
#         .footer-links a:hover { color: #333; }
#         .footer-links a.bold { font-weight: 700; color: #333; }
#         .address, .as_center { line-height: 1.6; font-size: 14px; color: #666; }
#         .address strong, .as_center strong { display: inline-block; margin-bottom: 8px; color: #333; font-size: 16px; }
#     </style>
# </head>
# <body>
#
#     <header class="header-container container">
#         <div class="logo">
#             <a href="/"><img src="logo.png" alt="서비스 로고"></a>
#         </div>
#         <nav>
#             <ul class="nav-menu">
#                 <li><a href="/about">은행소개</a></li>
#                 <li><a href="/deposit">예금·적금</a></li>
#                 <li><a href="/loan">대출</a></li>
#                 <li><a href="/card" class="active">카드</a></li>
#                 <li><a href="/support">고객센터</a></li>
#             </ul>
#         </nav>
#         <button class="header-btn">시작하기</button>
#     </header>
#
#     <div class="page-wrap">
#
#         <section class="hero">
#             <p class="eyebrow">Card</p>
#             <h1>결제할 때마다<br>바로 할인돼요</h1>
#             <p class="desc">다채로운 컬러의 체크카드와 결제 즉시 할인받는 제휴 신용카드.</p>
#         </section>
#
#         <div class="kpass-banner">
#             <div>
#                 <h3>토스뱅크 K-패스 카드 출시</h3>
#                 <p>대중교통 이용 시 최대 53% 환급, 이제 토스뱅크에서 가능해요.</p>
#             </div>
#             <button>자세히 보기</button>
#         </div>
#
#         <p class="section-title">체크카드</p>
#         <div class="card-grid">
#             <div class="card-item">
#                 <div class="card-visual blue">
#                     <div class="card-chip"></div>
#                     <div class="card-num">TOSS BANK CHECK</div>
#                 </div>
#                 <h3>토스뱅크 체크카드</h3>
#                 <p>심플한 디자인, 전월실적 조건 없이 모든 가맹점 0.1% 캐시백.</p>
#                 <div class="benefit-tags">
#                     <span>실적조건 없음</span>
#                     <span>전가맹점 캐시백</span>
#                 </div>
#                 <button>신청하기</button>
#             </div>
#             <div class="card-item">
#                 <div class="card-visual black">
#                     <div class="card-chip"></div>
#                     <div class="card-num">TOSS BANK BLACK</div>
#                 </div>
#                 <h3>토스뱅크 블랙 체크카드</h3>
#                 <p>프리미엄 블랙 디자인, 카페·편의점 5% 할인.</p>
#                 <div class="benefit-tags">
#                     <span>카페 5% 할인</span>
#                     <span>편의점 5% 할인</span>
#                 </div>
#                 <button>신청하기</button>
#             </div>
#             <div class="card-item">
#                 <div class="card-visual coral">
#                     <div class="card-chip"></div>
#                     <div class="card-num">TOSS BANK K-PASS</div>
#                 </div>
#                 <h3>토스뱅크 K-패스 카드</h3>
#                 <p>대중교통 최대 53% 환급, 알뜰교통카드 대체.</p>
#                 <div class="benefit-tags">
#                     <span>대중교통 환급</span>
#                     <span>최대 53%</span>
#                 </div>
#                 <button>신청하기</button>
#             </div>
#         </div>
#
#     </div>
#
#     <footer class="footer-container container">
#         <div class="address">
#             <div class="footer-links">
#                 <a href="#" class="bold">개인정보 처리방침</a>
#                 <a href="#">보호금융상품등록부</a>
#                 <a href="#">이용자유의사항</a>
#                 <a href="#">공지사항</a>
#                 <a href="#">경영공시</a>
#             </div>
#             <p><strong>토스뱅크</strong><br>
#                 사업자 등록번호 : 462-86-01671<br>
#                 주소 : 06133 서울특별시 강남구 테헤란로 131, 13층 (역삼동, 한국지식재산센터)<br>
#                 대표 : 이은미
#             </p>
#         </div>
#         <div class="as_center">
#             <p><strong>고객센터</strong><br>
#                 전화 : 1661-7654 (24시간 연중무휴)<br>
#                 해외전화 : +82-2-6975-9000<br>
#                 이메일 : <a href="/cdn-cgi/l/email-protection" class="__cf_email__" data-cfemail="b7dfd2db
# Out:
# Overwriting card.html

# %%
# %%writefile support.html
#
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#     <meta charset="UTF-8">
#     <title>고객센터 - 토스뱅크</title>
#     <style>
#         * { box-sizing: border-box; margin: 0; padding: 0; }
#
#         body {
#             background-color: #f5f5f5;
#             display: flex;
#             flex-direction: column;
#             min-height: 100vh;
#             gap: 15px;
#             font-family: 'Apple SD Gothic Neo', 'Pretendard', sans-serif;
#         }
#
#         .container {
#             display: flex;
#             justify-content: space-between;
#             align-items: center;
#             padding: 0 40px;
#             background-color: white;
#             box-shadow: 0 2px 5px rgba(0,0,0,0.05);
#             width: 100%;
#             max-width: 1400px;
#             margin: 0 auto;
#         }
#
#         .header-container { height: 80px; position: sticky; top: 0; z-index: 100; }
#         .logo img { height: 80px; width: auto; display: block; }
#         .nav-menu { display: flex; gap: 30px; list-style: none; }
#         .nav-menu li a { text-decoration: none; color: #333; font-weight: 500; font-size: 15px; }
#         .nav-menu li a:hover { color: #0064FF; }
#         .nav-menu li a.active { color: #0064FF; font-weight: 700; }
#         .header-btn {
#             background: #0064FF; color: white; border: none;
#             padding: 10px 20px; border-radius: 8px;
#             font-size: 14px; font-weight: 600; cursor: pointer;
#         }
#
#         .page-wrap { max-width: 1400px; margin: 0 auto; width: 100%; padding: 40px; flex-grow: 1; }
#
#         .hero {
#             background: linear-gradient(135deg, #0064FF 0%, #6600FF 100%);
#             border-radius: 20px;
#             padding: 70px 60px;
#             color: white;
#             margin-bottom: 40px;
#         }
#         .hero p.eyebrow { font-size: 13px; letter-spacing: 2px; color: rgba(255,255,255,0.6); margin-bottom: 16px; }
#         .hero h1 { font-size: 38px; font-weight: 900; line-height: 1.3; margin-bottom: 16px; }
#         .hero p.desc { font-size: 15px; color: rgba(255,255,255,0.8); line-height: 1.7; }
#
#         /* 연락 채널 */
#         .channel-grid { display: flex; gap: 20px; margin-bottom: 30px; }
#         .channel-card {
#             flex: 1;
#             background: white;
#             border: 1px solid #eee;
#             border-radius: 16px;
#             padding: 30px;
#             text-align: center;
#         }
#         .channel-card .icon { font-size: 36px; margin-bottom: 14px; }
#         .channel-card h3 { font-size: 16px; font-weight: 800; margin-bottom: 6px; color: #111; }
#         .channel-card .contact-num { font-size: 20px; font-weight: 900; color: #0064FF; margin: 10px 0; }
#         .channel-card p { font-size: 12px; color: #aaa; line-height: 1.6; }
#         .channel-card button {
#             margin-top: 16px;
#             width: 100%;
#             padding: 11px;
#             background: #f0f4ff;
#             color: #0064FF;
#             border: none;
#             border-radius: 10px;
#             font-size: 13px;
#             font-weight: 700;
#             cursor: pointer;
#         }
#
#         /* FAQ */
#         .faq-section {
#             background: white;
#             border: 1px solid #eee;
#             border-radius: 16px;
#             padding: 32px;
#             margin-bottom: 20px;
#         }
#         .faq-section h2 { font-size: 20px; font-weight: 800; margin-bottom: 24px; color: #111; }
#
#         .faq-item {
#             border-bottom: 1px solid #f0f0f0;
#             padding: 18px 0;
#         }
#         .faq-item:last-child { border-bottom: none; }
#
#         .faq-q {
#             display: flex;
#             gap: 12px;
#             align-items: center;
#             cursor: pointer;
#         }
#         .faq-q .q-badge {
#             min-width: 24px;
#             height: 24px;
#             background: #0064FF;
#             color: white;
#             border-radius: 6px;
#             display: flex;
#             align-items: center;
#             justify-content: center;
#             font-size: 12px;
#             font-weight: 900;
#         }
#         .faq-q span { font-size: 14px; font-weight: 600; color: #222; }
#         .faq-a {
#             margin-top: 12px;
#             margin-left: 36px;
#             font-size: 13px;
#             color: #666;
#             line-height: 1.7;
#         }
#
#         /* 공지사항 */
#         .notice-section {
#             background: white;
#             border: 1px solid #eee;
#             border-radius: 16px;
#             padding: 32px;
#         }
#         .notice-section h2 { font-size: 20px; font-weight: 800; margin-bottom: 24px; color: #111; }
#
#         .notice-row {
#             display: flex;
#             justify-content: space-between;
#             align-items: center;
#             padding: 16px 0;
#             border-bottom: 1px solid #f5f5f5;
#         }
#         .notice-row:last-child { border-bottom: none; }
#         .notice-row .tag {
#             display: inline-block;
#             font-size: 11px;
#             background: #e8f0ff;
#             color: #0064FF;
#             padding: 2px 8px;
#             border-radius: 4px;
#             font-weight: 600;
#             margin-right: 10px;
#         }
#         .notice-row .title { font-size: 14px; color: #333; }
#         .notice-row .date { font-size: 12px; color: #aaa; }
#
#         /* 푸터 */
#         .footer-container { height: auto; padding: 40px; gap: 40px; align-items: flex-start; background: #f8f8f8; }
#         .footer-links { display: flex; gap: 16px; margin-bottom: 16px; flex-wrap: wrap; }
#         .footer-links a { font-size: 12px; color: #888; text-decoration: none; }
#         .footer-links a:hover { color: #333; }
#         .footer-links a.bold { font-weight: 700; color: #333; }
#         .address, .as_center { line-height: 1.6; font-size: 14px; color: #666; }
#         .address strong, .as_center strong { display: inline-block; margin-bottom: 8px; color: #333; font-size: 16px; }
#     </style>
# </head>
# <body>
#
#     <header class="header-container container">
#         <div class="logo">
#             <a href="/"><img src="logo.png" alt="서비스 로고"></a>
#         </div>
#         <nav>
#             <ul class="nav-menu">
#                 <li><a href="/about">은행소개</a></li>
#                 <li><a href="/deposit">예금·적금</a></li>
#                 <li><a href="/loan">대출</a></li>
#                 <li><a href="/card">카드</a></li>
#                 <li><a href="/support" class="active">고객센터</a></li>
#             </ul>
#         </nav>
#         <button class="header-btn">시작하기</button>
#     </header>
#
#     <div class="page-wrap">
#
#         <section class="hero">
#             <p class="eyebrow">Customer Support</p>
#             <h1>365일 24시간<br>언제든 도와드려요</h1>
#             <p class="desc">전화, 채팅, 이메일 어떤 방법으로도 연락 주세요.</p>
#         </section>
#
#         <div class="channel-grid">
#             <div class="channel-card">
#                 <div class="icon">📞</div>
#                 <h3>전화 상담</h3>
#                 <div class="contact-num">1661-7654</div>
#                 <p>24시간 연중무휴<br>공휴일 포함 운영</p>
#                 <button>전화하기</button>
#             </div>
#             <div class="channel-card">
#                 <div class="icon">💬</div>
#                 <h3>채팅 상담</h3>
#                 <div class="contact-num">앱에서 바로</div>
#                 <p>토스뱅크 앱 내<br>실시간 채팅 상담</p>
#                 <button>앱 열기</button>
#             </div>
#             <div class="channel-card">
#                 <div class="icon">✉</div>
#                 <h3>이메일 문의</h3>
#                 <div class="contact-num" style="font-size: 14px;"><a href="/cdn-cgi/l/email-protection" class="__cf_email__" data-cfemail="6e060b021e2e1a011d1d0c0f0005400d0103">[email&#160;protected]</a></div>
#                 <p>영업일 기준 1~2일<br>내 답변 드려요</p>
#                 <button>이메일 보내기</button>
#             </div>
#             <div class="channel-card">
#                 <div class="icon">🌏</div>
#                 <h3>해외에서 전화</h3>
#                 <div class="contact-num" style="font-size: 15px;">+82-2-6975-9000</div>
#                 <p>해외 체류 중에도<br>24시간 상담 가능</p>
#                 <button>전화하기</button>
#             </div>
#         </div>
#
#         <div class="faq-section">
#             <h2>자주 묻는 질문</h2>
#
#             <div class="faq-item">
#                 <div class="faq-q">
#                     <div class="q-badge">Q</div>
#                     <span>토스뱅크 계좌는 어떻게 개설하나요?</span>
#                 </div>
#                 <div class="faq-a">토스 앱을 설치한 후 '토스뱅크 통장 만들기'를 선택하고 신분증 촬영, 본인인증 절차를 완료하면 약 3분 만에 계좌가 개설됩니다. 영업점 방문 없이 비대면으로 가능합니다.</div>
#             </div>
#             <div class="faq-item">
#                 <div class="faq-q">
#                     <div class="q-badge">Q</div>
#                     <span>이자는 언제 지급되나요?</span>
#                 </div>
#                 <div class="faq-a">토스뱅크 통장은 매일 밤 자동으로 이자가 계산되어 다음날 입금됩니다. 하루만 돈을 넣어두어도 이자가 발생합니다.</div>
#             </div>
#             <div class="faq-item">
#                 <div class="faq-q">
#                     <div class="q-badge">Q</div>
#                     <span>대출 신청 시 신용점수에 영향이 있나요?</span>
#                 </div>
#                 <div class="faq-a">한도 조회 시에는 신용점수에 영향을 주지 않습니다. 실제 대출 실행 시에만 신용조회가 이루어집니다.</div>
#             </div>
#             <div class="faq-item">
#                 <div class="faq-q">
#                     <div class="q-badge">Q</div>
#                     <span>외화 환전 수수료가 정말 없나요?</span>
#                 </div>
#                 <div class="faq-a">네, 토스뱅크 외환 서비스는 평생 무료 환전을 제공합니다. 환전 수수료, 송금 수수료 모두 0원입니다.</div>
#             </div>
#         </div>
#
#         <div class="notice-section">
#             <h2>공지사항</h2>
#             <div class="notice-row">
#                 <div><span class="tag">공지</span><span class="title">토스뱅크 K-패스 카드 출시 안내</span></div>
#                 <span class="date">2025.03.01</span>
#             </div>
#             <div class="notice-row">
#                 <div><span class="tag">이벤트</span><span class="title">모임통장 개설 시 최대 3만원 혜택</span></div>
#                 <span class="date">2025.02.20</span>
#             </div>
#             <div class="notice-row">
#                 <div><span class="tag">점검</span><span class="title">외환 서비스 점검 안내 (3/10 02:00~04:00)</span></div>
#                 <span class="date">2025.02.15</span>
#             </div>
#             <div class="notice-row">
#                 <div><span class="tag">이벤트</span><span class="title">첫 대출 고객 금리 우대 이벤트</span></div>
#                 <span class="date">2025.02.10</span>
#             </div>
#         </div>
#
#     </div>
#
#     <footer class="footer-container container">
#         <div class="address">
#             <div class="footer-links">
#                 <a href="#" class="bold">개인정보 처리방침</a>
#                 <a href="#">보호금융상품등록부</a>
#                 <a href="#">이용자유의사항</a>
#                 <a href="#">공지사항</a>
#                 <a href="#">경영공시</a>
#             </div>
#             <p><strong>토스뱅크</strong><br>
#                 사업자 등록번호 : 462-86-01671<br>
#                 주소 : 06133 서울특별시 강남구 테헤란로 131, 13층 (역삼동, 한국지식재산센터)<br>
#                 대표 : 이은미
#             </p>
#         </div>
#         <div class="as_center">
#             <p><strong>고객센터</strong><br>
#                 전화 : 1661-7654 (24시간 연중무휴)<br>
#                 해외전화 : +82-2-697
# Out:
# Overwriting support.html

# %%
# !nohup node server.js > server.log 2>&1 &

# %%
# !tail -n 20 server.log

# %%
# !npm install -g cloudflared
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏
# changed 1 package in 2s
# ⠏

# %%
# !nohup cloudflared tunnel --url http://localhost:3000 > tunnel.log 2>&1 &

# %%
# !tail -n 20 tunnel.log

# %%
# !grep -o "https://[a-zA-Z0-9.-]*\.trycloudflare.com" tunnel.log |tail -n 1
