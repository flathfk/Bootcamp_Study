# %% [markdown]
# <a href="https://colab.research.google.com/github/flathfk/Bootcamp_Study/blob/main/260507.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# MongoDB 7.0 설치 및 실행 (매 세션마다 실행)

# 1. 필수 패키지 + GPG 키
# !sudo apt-get update -qq
# !sudo apt-get install -y gnupg curl -qq
# !curl -fsSL https://www.mongodb.org/static/pgp/server-7.0.asc | sudo gpg -o /usr/share/keyrings/mongodb-server-7.0.gpg --dearmor

# 2. 저장소 등록
# !echo "deb [ arch=amd64,arm64 signed-by=/usr/share/keyrings/mongodb-server-7.0.gpg ] https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/7.0 multiverse" | sudo tee /etc/apt/sources.list.d/mongodb-org-7.0.list

# 3. 설치
# !sudo apt-get update -qq
# !sudo apt-get install -y mongodb-org -qq

# 4. 디렉토리 생성
# !sudo mkdir -p /data/db /var/log/mongodb
# !sudo chown -R $(id -un) /data/db /var/log/mongodb

# 5. 실행
# !mongod --fork --logpath /var/log/mongodb/mongod.log

# 6. 확인
# !ps -ef | grep mongod
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 3.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# (Reading database ... 118194 files and directories currently installed.)
# Preparing to unpack .../libcurl4-openssl-dev_7.81.0-1ubuntu1.24_amd64.deb ...
# Unpacking libcurl4-openssl-dev:amd64 (7.81.0-1ubuntu1.24) over (7.81.0-1ubuntu1.23) ...
# Preparing to unpack .../curl_7.81.0-1ubuntu1.24_amd64.deb ...
# ...
